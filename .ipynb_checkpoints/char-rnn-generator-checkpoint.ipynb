# %%
import unidecode
import string
import random
import re
import torch
import torch.nn as nn
from torch.autograd import Variable

all_characters = string.printable
n_characters = len(all_characters)

# Unix code used to remove relic binary
# tr -cd '\11\12\15\40-\176' < file-with-binary-chars > clean-file

file = unidecode.unidecode(open('/home/paperspace/Documents/GitHub/data/cleanproposaltxt.txt').read())
file_len = len(file)
print('file_len =', file_len)
# Out:
# file_len = 63346715

# %%
use_cuda = torch.cuda.is_available()
dtype = torch.cuda.LongTensor if use_cuda else torch.LongTensor

# %%
chunk_len = 400

def random_chunk():
    start_index = random.randint(0, file_len - chunk_len)
    end_index = start_index + chunk_len + 1
    return file[start_index:end_index]

print(random_chunk())
# Out:
# requency drives and computer equipment require humidity control as well as heated storage. In cases where the manufacturer and specifications have this requirement items shall be kept in an indoor heated humidity controlled room or enclosure.
#
# QUARANTINED MATERIALS
#
# Quarantined materials shall be kept out of reach until resolution has been agreed with the vendor in question. Procedures shall be fol

# %%
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, n_layers=1):
        super(RNN, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers
        
        self.encoder = nn.Embedding(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers)
        self.decoder = nn.Linear(hidden_size, output_size)
    
    def forward(self, input, hidden):
        input = self.encoder(input.view(1, -1))
        output, hidden = self.gru(input.view(1, 1, -1), hidden)
        output = self.decoder(output.view(1, -1))
        return output, hidden

    def init_hidden(self):
        return Variable(torch.zeros(self.n_layers, 1, self.hidden_size).cuda())

# %%
# Turn string into list of longs
def char_tensor(string):
    if use_cuda:
        tensor = torch.zeros(len(string)).long().cuda()
    else:
        tensor = torch.zeros(len(string)).long()
    for c in range(len(string)):
        tensor[c] = all_characters.index(string[c])
    return Variable(tensor)

print(char_tensor('abcDEF'))
# Out:
# Variable containing:
#  10
#  11
#  12
#  39
#  40
#  41
# [torch.cuda.LongTensor of size 6 (GPU 0)]

# %%
def random_training_set():    
    chunk = random_chunk()
    inp = char_tensor(chunk[:-1])
    target = char_tensor(chunk[1:])
    return inp, target

# %%
def evaluate(prime_str='A', predict_len=200, temperature=0.5):
    hidden = decoder.init_hidden()
    prime_input = char_tensor(prime_str)
    predicted = prime_str

    # Use priming string to "build up" hidden state
    for p in range(len(prime_str) - 1):
        _, hidden = decoder(prime_input[p], hidden)
    inp = prime_input[-1]
    
    for p in range(predict_len):
        output, hidden = decoder(inp, hidden)
        
        # Sample from the network as a multinomial distribution
        output_dist = output.data.view(-1).div(temperature).exp()
        top_i = torch.multinomial(output_dist, 1)[0]
        
        # Add predicted character to string and use as next input
        predicted_char = all_characters[top_i]
        predicted += predicted_char
        inp = char_tensor(predicted_char)

    return predicted

# %%
import time, math

def time_since(since):
    s = time.time() - since
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

# %%
def train(inp, target):
    hidden = decoder.init_hidden()
    decoder.zero_grad()
    loss = 0

    for c in range(chunk_len):
        output, hidden = decoder(inp[c], hidden)
        loss += criterion(output, target[c])

    loss.backward()
    decoder_optimizer.step()

    return loss.data[0] / chunk_len

# %%
def save_best(loss, best_loss):
    if best_loss == None:
        best_loss = loss
        file = 'saved_models/best_save_model.p'
        torch.save(decoder.state_dict(), file)
    elif loss < best_loss:
        best_loss = loss
        file = 'saved_models/best_save_model.p'
        torch.save(decoder.state_dict(), file)
    return best_loss

# %%
n_epochs = 18000
print_every = 100
plot_every = 10
hidden_size = 512
n_layers = 3
lr = 0.005


def RNN_ifcuda(n_characters, hidden_size, n_layers):
    model = RNN(n_characters, hidden_size, n_characters, n_layers)
    if use_cuda:
        model = model.cuda()
    return model
    

decoder = RNN_ifcuda(n_characters, hidden_size, n_layers)
decoder_optimizer = torch.optim.Adam(decoder.parameters(), lr=lr)
criterion = nn.CrossEntropyLoss()

start = time.time()
all_losses = []
loss_avg = 0
best_loss = None

for epoch in range(1, n_epochs + 1):
    loss = train(*random_training_set())
    save_best(loss, best_loss)
    loss_avg += loss

    if epoch % print_every == 0:
        print('[%s (%d %d%%) %.4f]' % (time_since(start), epoch, epoch / n_epochs * 100, loss))
        print(evaluate('SNC', 100), '\n')

    if epoch % plot_every == 0:
        all_losses.append(loss_avg / plot_every)
        loss_avg = 0
# Out:
#  2s (100 0%) 2.7011]
# SNC>ULUU&8Y%%XG&9X!TU'9ULU1DGUU%JUk&5S=P9U&1Th>U1OS\NYRRYNRY
# AYIroschor
#
# Icide meced ored re le s
# core
#
#  1s (200 1%) 2.4209]
# SNC0R7UU-UUROTRONOUUNROTOLUOTONTTORPFNRFRRR0UNRTONTONRNRERO.RUBURROLUFOLROBOFFUNRRENOIRUURAOLR000UUNONR
#
#  59s (300 1%) 2.7031]
# SNC
# Yn Contre tate the sestions the strester sent sent Part Contremes the Contrement Contrestate Tred t
#
#  59s (400 2%) 2.0615]
# SNCENERENENERSSE SNSENEYxuticine resuted prolities, prover or the the revertes ente proces of the sure
#
#  57s (500 2%) 2.0877]
# SNCONTRIRIRTONTTINTONGTNTOR TONTNOTONTTONTRADINCONTNTINTONTRDONTT NONRGONTDINTINININGONTNGIRTONTT SONTG
#
#  57s (600 3%) 1.9551]
# SNC-Lavall proceers, prococontrovel to des to for the the the on the the be the ang the the, recosion t
#
#  55s (700 3%) 2.0462]
# SNCONNNNEENTRENNRETINENTRG100310101010301000020200000,000060	ENTINENESS Ranitis, planted oned Sucted to
#
#  53s (800 4%) 1.9927]
# SNCONTRCOTIER
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ANPPROLALICEPRAL APTIORE RECEPTRICPRONIPAGT INCITIRENPTIRTOR GO
#
#  50s (900 5%) 1.7853]
# SNC-R-CORRTROR parting Ranan sist and inding report and or in and repork departarting of strament of pr
#
#  49s (1000 5%) 2.1119]
# SNC-Lavalis according of action the procated to a propomplite.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Spected wermerate cocte
#
#  46s (1100 6%) 2.3945]
# SNC-Lavalin the control be be Prove acte to the Contract the an the the the ext at the ele commber the
#
#  43s (1200 6%) 1.8799]
# SNCCLLLOL3 Section the and or compronstruction the roced the to the cortermant the review with out the
#
#  40s (1300 7%) 2.1764]
# SNC-Lavalince contractor in the project out and resivent Managements of in shall supplin collllllice of
#
#  38s (1400 7%) 2.9834]
# SNC-Lax 3   SSE SNC-LISISE project st the the the deview and  prope the for Ster a the Se dent the to E
#
#  34s (1500 8%) 1.7642]
# SNC-Lavalin the induressincion of the procurement the the projectiiness contrice siticing the the revie
#
#  31s (1600 8%) 1.8863]
# SNC-Lavalin and in of bevices will be Re-able be be mane will be Malke be by bot Project by be be the b
#
#  27s (1700 9%) 2.9351]
# SNC-LALI-KLALI-DI-TIG
#
#
#
#
#
#
# G55-
# CORY
# 1111111-51111111-111111111-11111111111111-111111111-1111111111111
#
#  23s (1800 10%) 2.3105]
# SNC-Lavality the in the Contraction Insializal tave be Cesign Control in and or in Contractives of the
#
#  19s (1900 10%) 1.5996]
# SNC-Lavalin process and expering and shoped forly required project whill day ally and projection and li
#
#  13s (2000 11%) 2.0658]
# SNC-L-Lavalins in the sections recoriated infor the consentions shall be procedured by conditions as or
#
#  8s (2100 11%) 2.0060]
# SNC-Lavaling and a and and manage of arear process stathates, be are are to has as all asshariable any
#
#  3s (2200 12%) 1.6482]
# SNC-Lavalin
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Luse In in result and in require tap the to resull and and the project in t
#
#  58s (2300 12%) 1.9571]
# SNC-Lavalin the the Conforming as the the in the the scomplution the presult Conting the procedure ill
#
#  53s (2400 13%) 1.9285]
# SNC-Lavalins sconstruction any ressolerage the concels compling controce and for executing incontractio
#
#  48s (2500 13%) 1.8716]
# SNC-Lavalin as and and and Company and Alarson and is accroies and and by as and and as sure and Contro
#
#  45s (2600 14%) 1.8877]
# SNC-Lavalin an conform consiblity be and control any the Project of the be Project shich be recion and
#
#  43s (2700 15%) 2.2950]
# SNC-Lavalin are an comments of the to sure any action procedure proces and Procedure an stan the Procur
#
#  39s (2800 15%) 2.2420]
# SNC-Lavalin or the project in programs, and to the work and the a project and by the project in the pro
#
#  37s (2900 16%) 1.8314]
# SNC-Lavalins active of af and implities for in project flan form pressulling fasumbted ablant pressif i
#
#  37s (3000 16%) 2.0774]
# SNC-Lavalines and and and and sisinal and and to anale tation and invering and and for the pillineering
#
#  31s (3100 17%) 2.3370]
# SNC-Lavalin for of staration and hour or and detica Resedule of Part Rall be Refedulity such Revay hich
#
#  28s (3200 17%) 1.8832]
# SNC-LIDINDINEDIDDMINDD00 CLIADITIONDT OMIRMMMMTIIMANDCTIONTDIIM
# TIMITIONNDTRCMORTRACTICMMOTIONS
# The and
#
#  23s (3300 18%) 1.7423]
# SNC-Lavalin or the propide Canages formas including, and the provide out the in the consution the signi
#
#  19s (3400 18%) 1.7468]
# SNC-Lavalin strant of Coment and or the project materagation of the stat the procurement procurement sc
#
#  15s (3500 19%) 1.6373]
# SNC-Lavaling inthor ach in and the extail of and and the Project, that the Contract sure and sured mana
#
#  10s (3600 20%) 1.6588]
# SNC-Lavalining has thavid or or has the recovering the the intems hat dusing in the thived of thation s
#
#  6s (3700 20%) 1.8301]
# SNC-Lavalins and and by the adces and atderian and duration, and the at and bay the process, costat Pro
#
#  2s (3800 21%) 2.0278]
# SNCENNERENTENE ANCTOR ONENENE inch of of asconsid and poconited by bused and and of develowing of consi
#
#  57s (3900 21%) 2.3634]
# SNC-Lavalited an the Commition such of the of Canition un of the Contraction Consurarde and the Comman
#
#  52s (4000 22%) 2.0146]
# SNC-Lavalin the Control the Controlly Control Contractortor, modition the Control Contrott-Conther the
#
#  47s (4100 22%) 2.1597]
# SNC-Lavalin this contractor and in of cond and on contractor the project deal the project to cost dat D
#
#  42s (4200 23%) 1.6798]
# SNC-Lavalin processign of of to contraction duticact proceduct procguced prociation process in and perf
#
#  37s (4300 23%) 1.9019]
# SNC-Lavaling and of that the prope of chater to any to and by prope of the or the At our ow the perer o
#
#  32s (4400 24%) 1.8219]
# SNC-Lavalin the Cork in the reat or the risk of thich on the and the to thigh to the Corks ED of our of
#
#  27s (4500 25%) 1.8861]
# SNC-Lavalin in and in and COVP and premance belial Case and shall reliveried as bere bilient undering a
#
#  22s (4600 25%) 1.9101]
# SNC-Laval a casing all consided and the Saccipline and en is locannt and and scontractor design all bal
#
#  18s (4700 26%) 2.3003]
# SNC-Laval Servicement and and and and of the propre of project and to bethendend promentato troun whiga
#
#  15s (4800 26%) 2.3829]
# SNC-Lavalining wit and the the the the the Experiation shall be the surtible and for the Project for th
#
#  10s (4900 27%) 1.9863]
# SNC-Lavaling Contract the propostruter shall stame of the for the proces (LE LE Contractor Reas Comptin
#
#  5s (5000 27%) 2.0302]
# SNC-Lavalin cording and dof required parification of bote or the for or contrelition to are compline an
#
#  0s (5100 28%) 1.7050]
# SNC-Lavaling and the be acture or in and be out unden in and and and any and mute by rese project disci
#
#  55s (5200 28%) 2.0255]
# SNC-Las the of project and to in to the Project of pontsing to sholl to the on to the Worke Project our
#
#  49s (5300 29%) 2.1932]
# SNCLILILILILILILI DORPITALSLLLLTELILELELIOTOR LILOR PERLIAR ODSLTRERSL LORLILILL SLIPILILILEEDERTERI PE
#
#  43s (5400 30%) 1.8920]
# SNC-Lavaling of Propost to the contractor of develowsion of the the the the shours SNC-Lavalition for t
#
#  40s (5500 30%) 1.7804]
# SNC-Laval 100RA IOR subcess at the proved the comport comport engineering the pection the project cours
#
#  35s (5600 31%) 1.8328]
# SNC-Lavalin or covering achical abe a deconding and in mo de all and maaddo and required for and decons
#
#  32s (5700 31%) 1.7464]
# SNC-Lavalin aripor to the project and in and and consions of and project will for of alive all all all
#
#  27s (5800 32%) 2.4588]
# SNC-COPACTIOR Pract 2 2000208 Contraction Contraction dided  paciting and and and and and and and and c
#
#  23s (5900 32%) 1.9753]
# SNC-Lavalin and contraction discilition in the for the contracing includ in and to control undation wil
#
#  19s (6000 33%) 2.0515]
# SNC-Lavalin and recurs consing subdinices be procurement copin and responsibilitions, and consin proces
#
#  14s (6100 33%) 2.3702]
# SNC-Lavalin and or and consical on consinernical construction will project the confor including a compl
#
#  7s (6200 34%) 2.1104]
# SNC-Laval be procedure sare will bre for will be be be ficingles be project will be for will be in and
#  1s (6300 35%) 1.9566]
# SNC-LE ESEX  EEEEEEEE EEEl withor the JEEEVEED3.				E														EXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
#  54s (6400 35%) 2.2636]
# SNC-Laval Stos SSCISS anage and the include anting the Sy Scontractor Systensing share the Sy SSC is su
#
#  48s (6500 36%) 1.8357]
# SNC-Lavalin Agrements and suppering in will be sersage and dessigned and frouns as and instruction and
#
#  42s (6600 36%) 1.9804]
# SNC-LONTONTRSS   Project on the Projector shall be or or Spart Propor Thecherial for or reports of the
#
#  35s (6700 37%) 2.1038]
# SNC-Lavall anas and and as and camany the PMarated and the and as the COMPANYY any ana anas any of that
#
#  30s (6800 37%) 1.9032]
# SNC-Lavalat
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  23s (6900 38%) 2.3266]
# SNC-Lav xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#
#  17s (7000 38%) 2.0899]
# SNC-LOEP $0000000000000000000000040000000000000  4   Project Murt Con add relocure ard by las a compera
#
#  11s (7100 39%) 2.8041]
# SNC-Lavalin Miith siel pherionment and the of the Sesties, cos in repordening of the RS B   ervication
#
#  5s (7200 40%) 2.1785]
# SNC-Lavaling the project relicent the CON
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Orent the project on cond hemor
#
#  58s (7300 40%) 2.2860]
# SNC-Lava in of concoding of th his to a conter of applicine oftion projection and the as and be inciont
#
#  52s (7400 41%) 2.1660]
# SNC-Lava and bort all be de are arent ach and and with to th the provide and a action and a and the in
#
#  45s (7500 41%) 1.9029]
# SNC-Lavaling: E Pare is in and be ares in an mion in pronical sects in and in the norming on istle requ
#
#  39s (7600 42%) 2.0368]
# SNC-Lavalate will en la equighs incontruchics and requirements in report to emports will be de de esic
#
#  33s (7700 42%) 1.8986]
# SNC-Lavale seeling de and be as in the of controuss invere and in execope the project suppersonater 7an
#
#  26s (7800 43%) 2.0732]
# SNC-Lasksuse expech shall by procumenty complish the as aus all as stech and the procall be shall bely
#
#  19s (7900 43%) 1.8943]
# SNC-Lat Lemport Lat Pand Perecep are the proving and commeding, of the Project any in and be the respec
#
#  12s (8000 44%) 1.9318]
# SNC-Lavale procure art secult sure tragemed the J-MGA AG G      JEVIATI 1  G    G  and Pract disted of
#
#  7s (8100 45%) 1.9091]
# SNC-Lavalint wich for therer and the of the Suarplin to nitien the trance Dand J00000000000000000000000
#
#  1s (8200 45%) 2.4431]
# SNC-Laval Awn the norgent the A0 4000007 Con with wil the the the Exxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#
#  56s (8300 46%) 2.0627]
# SNC-Lavale adde the as is the ERSE   projiew Ray addo the Os to procime repport procedi dive doculs by
#
#  51s (8400 46%) 2.6272]
# SNC-Lavalin on submentringed the sentractor take re distimite de inderation de and and the in the RIUD
#
#  45s (8500 47%) 2.0315]
# SNC-Lavale presport prepropering sherizalined project the pland project the persons the in the projects
#
#  40s (8600 47%) 2.1057]
# SNC-Laval progring will inglude the execter with the te the for the ressenited in the for the the to th
#
#  35s (8700 48%) 1.7260]
# SNC-Lavality engerice the Procedule resentation to and of the exectin and bateriner conted to the sure
#
#  30s (8800 48%) 2.2417]
# SNC-Lo as the be the nest fo for cone de for the fort not the for shecution costs foces enging de prect
#
#  24s (8900 49%) 2.0945]
# SNC-Laval Contraction the provectractication lo Ther provetiner provent lisul schachabilites ofreculive
#
#  20s (9000 50%) 2.2429]
# SNC-Lavalition s resses at the the incent to the contraction to the provid to the project as projice pr
#
#  15s (9100 50%) 1.7124]
# SNC-L-Lavall any the exeties the prarty and the the saficitities and and thes execure and any apple the
#
#  10s (9200 51%) 1.9352]
# SNC-Lavalin in accurary shally Sesuct affort, in complos of a COMPMPS PSCPSIA Shas ar rectime the Const
#
#  5s (9300 51%) 2.6072]
# SNC-Laval Setain              Secesol Seched SNC-Lavast Con Sarate to the SNC-Lavary or the SNC-Lalas S
#
#  0s (9400 52%) 1.8531]
# SNC-Lavaling BOMESS
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  57s (9500 52%) 2.4207]
# SNC-Lases, andedingly acontrications,, bybicility,uly and and,inges, bymistontrolated,,,,,,,,,.
#
#
#  52s (9600 53%) 2.4491]
# SNC-Lavalin SNC-LANAENNCENTENS
#
#
#
#
# SN-LANANTEFENSASES SNENNRACATTENINS
# Tonsed SN       B   Gerveris SNC
#
#  47s (9700 53%) 3.1534]
# SNC-Lavalinica ind project sumpanter review to the in the project exping suckuneriesed in project proje
#
#  43s (9800 54%) 2.0736]
# SNC-Laval and and will execifenging accontive requipment by gragent and prowided will be derilated and
#
#  38s (9900 55%) 2.5776]
# SNCTONTT
#
# TRATATIAT ANT AINTANTRA
# TEET
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# EsTER ANTRAL PECTRACT TRATATI
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  33s (10000 55%) 1.9391]
# SNC-Lavaling Project SNC-Lavaling and outor on the requement the malut forment of lesign fors and the l
#
#  28s (10100 56%) 2.6675]
# SNC) xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#
#  23s (10200 56%) 1.9902]
# SNC-Lavalin projects suchall be compressed by shall provect the proves formere will be complesses and m
#
#  18s (10300 57%) 2.2724]
# SNCLILILILINILILILIIIINS)
#
#
#  13s (10400 57%) 1.9163]
# SNC-Laval expectricaling Manad and and and and and instructing and in achicalinge, and and chall chalin
#
#  8s (10500 58%) 2.0038]
# SNC-LED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  4s (10600 58%) 2.2801]
# SNC-Lavalinican Consiencludinis Consplising Consibinilutions Plations) Consisting Constractors. Theil b
#
#  59s (10700 59%) 1.8953]
# SNC-Lavaling alowd by sost the derial supplation and all and is projects astic and complation as as pra
#
#  54s (10800 60%) 1.7560]
# SNC-Lavalin Savalin schall be escore all be the Constructo Lavalis shager requesall and required thall
#
#  48s (10900 60%) 1.9491]
# SNC-LIHICIONTRACTOR on the lommer le neer in the all be managere dersor 2he contrall be project and maj
#
#  44s (11000 61%) 1.6447]
# SNC-Lavalining Inall and contract the or completes of the excopel the All trecoumetal in of expalicate
#
#  39s (11100 61%) 2.6245]
# SNC-Lalana Project scoution and and scheration the project and in the CONTWIBIFITIIT Construction and C
#
#  35s (11200 62%) 1.7357]
# SNC-Lavallick Enduall in Fe contraction of Saune Exconsultion of the Procuction Proculical For Contraci
#
#  29s (11300 62%) 1.5014]
# SNC-Laval and and cuals any and such project and constractive contal pers and and and sucess and and sa
#
#  24s (11400 63%) 1.8308]
# SNC-Lavaling subjection of this Clist projecto complient in the contractors Scopering stabiling project
#
#  19s (11500 63%) 1.4944]
# SNC-Lavalin as that the to lised and conding commiticalinge and and contraction and for the constarize
#
#  14s (11600 64%) 2.1096]
# SNC-Lavaling Minstations or the in senting, and wations in the lerformant on the leter to the stemneema
#
#  9s (11700 65%) 1.5289]
# SNC-Lavalin of exxxpate any expecental as be process and of accope deceirs on execes in be enging and s
#
#  5s (11800 65%) 1.6523]
# SNC-Laval lated hour hat opplines provall that and and the process on have contract delives in control
#
#  0s (11900 66%) 1.9477]
# SNC-Lavaling Hurotaring and reve Hation Procurees for the and and the or the process for the Project wi
#
#  54s (12000 66%) 1.9808]
# SNC-Lavalin for ether suppred of the referces support repart hrave cons tures in the Desure complaction
#
#  49s (12100 67%) 2.5676]
# SNC-
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  44s (12200 67%) 2.3124]
# SNC-Lavalified team the informated by the to and prining and is be and starage and to sumed for and del
#
#  39s (12300 68%) 2.2596]
# SNC-Lavalin struction statem for the sectreas the is procedured will be prodicide in ten shall for pren
#  35s (12400 68%) 1.6734]
# SNC-LE
# AI PIONIIILO  ITIONIONSOS PMIOFIONIOSIOS IO
# PIMII POFIISIOFISESIOI IPOOS SO  PMI COMPI POP  PMI
#
#  32s (12500 69%) 2.1941]
# SNC-Lavalin to exters andersing the Project Agrated SFOKE
#
#
#
#
#
#
#
#
#
#
#
#
#
# D
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  27s (12600 70%) 2.2755]
# SNC-LED EPDERED E	EEDITID EDD EEDDE TERIORACT ETIOREE IABERDIORATIORACTORARTES TERED EDERIED PED EREDER
#
#  22s (12700 70%) 1.6755]
# SNCONTONESTUNIGE	ONT NGONTINIT ONGDINIGEXIGANTIATIONAGTIONENTID ANDITIONANY NONANTONDITITION SNCONTENTO
#
#  17s (12800 71%) 2.0046]
# SNC-Lavalin any proposes of the the applices any or propties wille and project of tection of the G-	PGS
#
#  12s (12900 71%) 2.2116]
# SNC-LAEGDEEEDEDEDDEDSUSTEGEES ESEUD SNC-LEED SNCLALTEAGEDDS EEEEDGED Subtigh its SE Supply Supplice the
#
#  8s (13000 72%) 1.6102]
# SNC-Lavalibicable and of and contract out sewy sevices and in the Project and will be shargariater war
#
#  4s (13100 72%) 1.9979]
# SNC-Lavalin are consessss and the matend of the proced to the renize for provided of sured stanges the
#
#  0s (13200 73%) 1.6998]
# SNC-Lavalin Project and proces or or intire process and to contractor Prope delived will be in includin
#
#  56s (13300 73%) 2.1451]
# SNC-LE COPANTEN
#
#
#
#
#
#
#
#
#
#
#
# E
#
#
#
#
#
#
#
#
#
# WERECPANE
#
#
# ACONTERCE
# NERIE
# TREE
# TRENERA The lollowe of the elle
#
#  51s (13400 74%) 2.2512]
# SNCET Provies Plant Priee to and dilu stantred by leligly Scill in the Contrig Plange in levement the t
#
#  46s (13500 75%) 1.6484]
# SNC  MEEMEASME  MEMENESAESONEESS
# ANNNSCEMEEENSE  TASEAS
# FALEEA  ANEESAN FEES ANENT NANT   SNCLSE FEDE S
#
#  40s (13600 75%) 2.0429]
# SNC Lavalind Respons wher the Achental Fector project will be perfor the and the calation for all be co
#
#  35s (13700 76%) 1.8893]
# SNC-Lavaling and includents the project in any shalaze will be be progrect the progre chanagement proce
#
#  30s (13800 76%) 1.9961]
# SNC-LA-LIT the intruction indocitiontriors.
# Forming of the provicimation or mevalinstrovion contration
#
#  26s (13900 77%) 2.7148]
# SNC-Lavall Dot The Planal Process Do stanization of ensterial and the and for suph of nowercon of the p
#
#  21s (14000 77%) 2.0450]
# SNC-Latale:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Schineering/to
#
# :Schonsinering
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  16s (14100 78%) 2.2554]
# SNC-AT and the exce and and includer fifices the and the deriouce to sterficalinges.
#
#
#
# Pesel Sursonsed
#
#  11s (14200 78%) 2.1938]
# SNC-Lavalin Plan (XX)2X5 Process
# X.		XXXXXXXXXXXXXXxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#
#  6s (14300 79%) 2.4825]
# SNC-Late Contractor of ene Coneed ouctoral and conterements and the Contractor coled opronter of the to
#
#  0s (14400 80%) 2.8356]
# SNC-Lavalin and soination in of the Constrom Constrolity (lin sowle of the be of the ort stroligant of
#
#  54s (14500 80%) 2.0856]
# SNCLI  and the pose to be ission the proposes and the Project and the Contract Rination in the Commeria
#
#  49s (14600 81%) 2.0823]
# SNCTONTRONTORTRANY Tayate Project and to the inging in the to provication and the to the project and th
#
#  43s (14700 81%) 1.9694]
# SNC-Lavement, dervose for the consulling the Comme the and presposis peremch constructives sugining the
#
#  39s (14800 82%) 2.2678]
# SNC-Lavalin and all be le all as sith the the management and the management tay the project on prograte
#
#  34s (14900 82%) 1.8312]
# SNC-Lavall be in Subilith a conting suble sube and be s bell bell sechedule serian and lailing all bel
#
#  29s (15000 83%) 1.7302]
# SNC-Laval Re a contro requesive ine and in in compable of all be in utardace or and accort in in a cont
#
#  24s (15100 83%) 1.8682]
# SNC-Lavalined and of all filuty the provisity in the partion SNC-Lavalin a the cording in supplation an
#
#  19s (15200 84%) 2.0096]
# SNC-LION CONTROST
#
#
#
#
#
#
#
# HHSE
# In the personstruction for a the providess in the presses the Corks (SN
#
#  13s (15300 85%) 2.1280]
# SNC-La                                                         IF   a expan and de a sub documbe of doc
#
#  9s (15400 85%) 1.8954]
# SNC-Laval Plor and the Project Pumproval Project Planary Project Pl of Prepon Project Project Planat Pl
#
#  3s (15500 86%) 1.9778]
# SNCTO UFTERTTOR IONTRACTOR TRONTRONTRONTRONTRONTRONTRONTRONTRATENTRET TOR Tilling frime are project pro
#
#  56s (15600 86%) 2.1482]
# SNC-Laval and EDEEGBESE
#
#
# I
#
# ESGENE BEESGEGGES BENEGGE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  50s (15700 87%) 1.9252]
# SNCC
# Lajained of at the the Pare woll contese eation of interion of the of anderized and to engineerine
#
#  44s (15800 87%) 1.9274]
# SNC-LL FFEEEEESE-EE SNC-LEEE CONTRO FRACTOR ETERESTINTERICTONTRO CONTRACTOR FIOR FFORKA ECTOR SNC-Laval
#
#  37s (15900 88%) 2.3779]
# SNC-Lavation of the contractor, to the struct of conssition the to the ofters and to (BB
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  31s (16000 88%) 2.0055]
# SNC-Lavalitions, of experiant prom reessationg required to the prodign nowding statigh engineer the str
#
#  24s (16100 89%) 2.5549]
# SNC-Lavalin to ill contruction of the schate the repial formect follow the procument of comport of the
#
#  18s (16200 90%) 2.6571]
# SNC-Lavalin (BANANTANINAANATENTANTINAATANTIANTANTANTIANT ANANTENGANTANTANTANT ANGANGANAATATANTANTANAATI
#
#  12s (16300 90%) 1.9456]
# SNCONS TNORS CONCTINTR Lata aly project with a and the projeect and a sall project and engines on the a
#
#  5s (16400 91%) 1.9613]
# SNC-Lavin Reconstal Rection and Chas the compent of and gection of CONRGLICONENTRONTR RFENTR MER CRI CE
#
#  59s (16500 91%) 1.7505]
# SNC-Lavalalites and restally and theachan that as thers
# Fignems and Ferks ach take that and includes an
#
#  52s (16600 92%) 2.1647]
# SNC-Lavalin Programents Plain of piscined the uses pelegy and the propies ethe proped ested bach proped
#
#  47s (16700 92%) 1.8745]
# SNC-Laval Suanted Be gortrice.
#
#
# 1333	Se prog outher and and in the engineering of the and on the seche
#
#  41s (16800 93%) 2.3818]
# SNC-Lavalin Seprocure: in shavalition of bor the of al and pere for the and be shares sistimite perteng
#
#  35s (16900 93%) 2.1775]
# SNC-Lavalited the oprices the Comper the to the precture the surection the or the to team reperies for
#
#  29s (17000 94%) 2.2507]
# SNCLe and of contruction of cost onsurighownee in ailed on id cont on contraction of controles ackuded
#
#  23s (17100 95%) 1.7901]
# SNCLII Contractor (6  Compent habe suction and the Pom 6ompontrical at Projects (66
#
# JIt othe to be be
#
#  18s (17200 95%) 1.9768]
# SNC-LINEL EEEED EEEEEEEEPEE eqELEE EEEEEDEEDEREEEEEL Mavall be lete engeerent the pere Engeer  e moreme
#
#  14s (17300 96%) 2.0836]
# SNCENEREEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEV
#
#  9s (17400 96%) 2.4270]
# SNCCC-Lavaition in Cl thaf and de experol of the and dartifinate will be destion the in diad the Mande
#
#  3s (17500 97%) 2.4274]
# SNC-Lave despors and and and any tomablound inesh bith and oup competatally wineling thors we econieds
#
#  59s (17600 97%) 2.1378]
# SNC-LEU LAG AED DEED  AFEED DEDEEEEEEEEEDEEEEEEAYE FFED DE MAEDEEDUUD EED  AD GEEDGAUDEDPUDEEMEEEEEDEEE
#
#  53s (17700 98%) 2.0140]
# SNC-Laterhination. Ineargent ane she aspioned and and the hastad dated and inge the uelenting plable pe
#
#  49s (17800 98%) 2.2763]
# SNC--LINYIN PD)					O	PRo PONTR wher the are Rort Mardow is PPO (PCONTR PORKKCTORy Mort al adde we Proj
#
#  44s (17900 99%) 1.8928]
# SNC-VAVE 16 1346 ThRuteriss Dustate the inseden withent and and insted the istalied dess and and in ent
#
#  39s (18000 100%) 2.2016]
# SNC-LAT      HERTTAT TORAAY       DSA - TEEED  TER PDETERT  1 TERTATTORT 1D PRACTORT PATY-MERT ESUMETT

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
# %matplotlib inline

plt.figure()
plt.plot(all_losses)
